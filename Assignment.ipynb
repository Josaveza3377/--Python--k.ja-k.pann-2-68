# %%
import numpy as np
import AssignmentPackage
student_name = input("กรุณากรอกชื่อนักศึกษา:")
total_score = float(input("กรุณากรอกคะแนนรวม:"))
AssignmentPackage.check_score(total_score)
AssignmentPackage.show_student_name(student_name)
# Out:
# กรุณากรอกชื่อนักศึกษา: รัชชาเทพ รัตนวงศ์
# กรุณากรอกคะแนนรวม: 70
# ผลการเรียน:
# B
# ชื่อนักศึกษา: รัชชาเทพ รัตนวงศ์
